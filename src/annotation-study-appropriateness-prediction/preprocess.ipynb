# %% [markdown]
# ### This file combines preprocesses the data and creates the cross validation split (Section 5 of the paper)

# %%
import os
import sys
import random
import numpy as np
import pandas as pd
from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit, MultilabelStratifiedKFold

# %%
#random_states = [random.randint(0, 2**32) for i in range(5)]

# %%
random_states = [2746317213, 1181241943, 958682846, 3163119785, 1812140441]

# %%
def seed_everything(seed: int):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)

# %%
seed_everything(42)

# %%
DIMS = [
    'Inappropriateness',
    'Toxic Emotions',
    'Excessive Intensity',
    'Emotional Deception',
    'Missing Commitment',
    'Missing Seriousness',
    'Missing Openness',
    'Missing Intelligibility',
    'Unclear Meaning',
    'Missing Relevance',
    'Confusing Reasoning',
    'Other Reasons',
    'Detrimental Orthography',
    'Reason Unclassified'
]

# %%
data_dir = '../../data/'
df = pd.read_csv(data_dir+'appropriateness-corpus/appropriateness_corpus_conservative.csv')

X = df.post_id.values
y = df[DIMS].values
for j, random_state in enumerate(random_states):
    i = 0
    mskf = MultilabelStratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)
    for train_index, tmp_index in mskf.split(X, y):
        split_dict = {}
        X_tmp, X_test = X[train_index], X[tmp_index]
        y_tmp, y_test = y[train_index], y[tmp_index]
        for post_id in X_test:
            split_dict[post_id] = 'TEST'

        msss = MultilabelStratifiedShuffleSplit(n_splits=1, test_size=0.125, random_state=42)
        for valid_index, test_index in msss.split(X_tmp, y_tmp):
            X_train, X_valid = X_tmp[valid_index], X_tmp[test_index]
            for post_id in X_train:
                split_dict[post_id] = 'TRAIN'
            for post_id in X_valid:
                split_dict[post_id] = 'VALID'
        df['fold{}.{}'.format(j,i)] = df['post_id'].apply(lambda x: split_dict[x])
        i+=1
df['arg_issue'] = df[['issue','post_text']].apply(lambda x: ' '.join(x), axis = 1)
df.to_csv(data_dir+'appropriateness-corpus/appropriateness_corpus_conservative_w_folds.csv')

# %%
df.head()
# Out:
#    post_id  source_dataset                                              issue  \
# 0        0               0          Is the school uniform a good or bad idea:
# 1        1               0          Is the school uniform a good or bad idea:
# 2        2               0                      Firefox vs internet explorer:
# 3        3               0  If your spouse committed murder and he or she ...
# 4        4               0  If your spouse committed murder and he or she ...
#
#                                            post_text  Inappropriateness  \
# 0  students should wear what they like and feel f...                  1
# 1  people cant be forced to wear school uniforms,...                  1
# 2  That form of argument degrades this forum, and...                  1
# 3  I wouldnt turn her in becuase she is my wife. ...                  0
# 4  No I wouldn't turn in my spouse. Just because ...                  1
#
#    Toxic Emotions  Excessive Intensity  Emotional Deception  \
# 0               0                    0                    0
# 1               0                    0                    0
# 2               1                    0                    1
# 3               0                    0                    0
# 4               0                    0                    0
#
#    Missing Commitment  Missing Seriousness  ...  fold3.1  fold3.2  fold3.3  \
# 0                   0                False  ...    TRAIN    TRAIN    TRAIN
# 1                   1                False  ...    TRAIN    TRAIN    VALID
# 2                   1                 True  ...     TEST    TRAIN    TRAIN
# 3                   0                False  ...    TRAIN    TRAIN    TRAIN
# 4                   1                False  ...    TRAIN    TRAIN    VALID
#
#    fold3.4  fold4.0  fold4.1  fold4.2  fold4.3 fold4.4  \
# 0     TEST    TRAIN    TRAIN    TRAIN    TRAIN    TEST
# 1    TRAIN    TRAIN     TEST    TRAIN    VALID   TRAIN
# 2    TRAIN    TRAIN    TRAIN    TRAIN     TEST   VALID
# 3    TRAIN    TRAIN     TEST    TRAIN    TRAIN   TRAIN
# 4    TRAIN    TRAIN    TRAIN    TRAIN    TRAIN    TEST
#
#                                            arg_issue
# 0  Is the school uniform a good or bad idea: stud...
# 1  Is the school uniform a good or bad idea: peop...
# 2  Firefox vs internet explorer: That form of arg...
# 3  If your spouse committed murder and he or she ...
# 4  If your spouse committed murder and he or she ...
#
# [5 rows x 44 columns]
