# %% [markdown]
# ### This file prints some examples for each of the sub-dimensions of the taxonomy

# %%
import pandas as pd
import krippendorff
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
import ast
import math
from collections import Counter
from itertools import combinations
from statsmodels.stats import inter_rater as irr

# %%
pd.set_option('display.max_colwidth', None)

# %%
data_dir = '../../data/'

# %%
df_full = pd.read_csv(data_dir+'appropriateness-corpus/appropriateness_corpus_full.csv')

# %%
df_full.head()
# Out:
#    post_id  source_dataset  \
# 0        0               0
# 1        1               0
# 2        2               0
# 3        3               0
# 4        4               0
#
#                                                                                    issue  \
# 0                                              is-the-school-uniform-a-good-or-bad-idea-
# 1                                              is-the-school-uniform-a-good-or-bad-idea-
# 2                                                           firefox-vs-internet-explorer
# 3  if-your-spouse-committed-murder-and-he-or-she-confided-in-you-would-you-turn-them-in-
# 4  if-your-spouse-committed-murder-and-he-or-she-confided-in-you-would-you-turn-them-in-
#
# ...

# %%
df_full[
    (df_full['emotion_1']==1) &
    (df_full['emotion_2']==3) &
    (df_full['commitment']!=1) &
    (df_full['confusion']!=1) &
    (df_full['other_']!=1)
]
# Out:
#      post_id  source_dataset  \
# 418      418               1
#
#                                                                                                 issue  \
# 418  If given the choice what way would you vote for the death penalty to be brought back in Britain?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                        post_text  \
# ...

# %%
df_full[
    (df_full['emotion_1']==3) &
    (df_full['emotion_2']==1) &
    (df_full['commitment']!=1) &
    (df_full['confusion']!=1) &
    (df_full['other_']!=1)
]
# Out:
#       post_id  source_dataset  \
# 145       145               2
# 191       191               0
# 247       247               1
# 423       423               1
# 802       802               0
# 883       883               1
# 1216     1216               2
# 1308     1308               0
# 1416     1416               0
#
#                                                                                                                                                        issue  \
# 145                                                                                    iPhone vs. Blackberry-- Stance: iPhone : The next revolution of Apple
# 191                                                                                                                                    evolution-vs-creation
# 247                                                                                can the police keep your car permantly if you have 3rd suspended license?
# ...

# %%
df_full[
    (df_full['commitment_1']==1) &
    (df_full['commitment_2']==3) &
    (df_full['emotion']!=1) &
    (df_full['confusion']!=1) &
    (df_full['other_']!=1)
]
# Out:
#       post_id  source_dataset  \
# 13         13               0
# 78         78               1
# 797       797               0
# 818       818               0
# 832       832               0
# 833       833               0
# 948       948               0
# 1117     1117               0
# 1124     1124               0
# 1294     1294               0
# 1419     1419               0
# 1422     1422               0
# 1732     1732               0
# 1735     1735               0
# 1746     1746               0
# 1921     1921               0
#
#                                                                                       issue  \
# 13                                               india-has-the-potential-to-lead-the-world-
# 78                                                         Do you know who created slavery?
# 797                                                                          is-porn-wrong-
# ...

# %%
df_full[
    (df_full['commitment_1']==3) &
    (df_full['commitment_2']==1) &
    (df_full['emotion']!=1) &
    (df_full['confusion']!=1) &
    (df_full['other_']!=1)
]
# Out:
#      post_id  source_dataset  \
# 9          9               0
# 57        57               0
# 68        68               0
# 174      174               0
# 193      193               0
# 611      611               2
#
#                                                                           issue  \
# 9                                                       tv-is-better-than-books
# 57                                                  gay-marriage-right-or-wrong
# 68                                                       pro-choice-vs-pro-life
# 174                                                              is-porn-wrong-
# 193                                                              is-porn-wrong-
# 611  This House Believes That Metal Music is Evil-- Stance: Metal Music is Evil
#
# ...

# %%
df_full[
    (df_full['confusion_1']==1) &
    (df_full['confusion_2']==3) &
    (df_full['confusion_3']==4) &
    (df_full['emotion']!=1) &
    (df_full['commitment']!=1) &
    (df_full['other_']!=1)
]
# Out:
#     post_id  source_dataset                  issue  \
# 24       24               0  evolution-vs-creation
#
#                                                                                                                                                               post_text  \
# 24  Believing "Evolution" as in Darwinism and the like, is like believing the puzzle can be solved by pouring the pieces out because two pieces kind of stuck together.
#
#     appropriateness  emotion  emotion_1  emotion_2  commitment  commitment_1  \
# 24                2        3          3          3           3             3
#
#     commitment_2  confusion  confusion_1  confusion_2  confusion_3  other_  \
# 24             3          1            1            3            4       3
#
#     other_1  other_2
# 24        3        3

# %%
df_full[
    (df_full['confusion_1']==3) &
    (df_full['confusion_2']==1) &
    (df_full['confusion_3']==3) &
    (df_full['emotion']!=1) &
    (df_full['commitment']!=1) &
    (df_full['other_']!=1)
]
# Out:
#       post_id  source_dataset  \
# 800       800               0
# 1018     1018               1
# 1103     1103               0
# 1166     1166               0
# 1479     1479               0
# 1672     1672               1
# 1744     1744               0
# 1765     1765               0
# 1924     1924               0
# 2105     2105               0
#
#                                                      issue  \
# 800                                  evolution-vs-creation
# 1018         Is it illegal to record a phone conversation?
# 1103                               tv-is-better-than-books
# 1166                                pro-choice-vs-pro-life
# 1479    should-physical-education-be-mandatory-in-schools-
# 1672  Is it patriotic to make bed sheets out of your flag?
# 1744                                        is-porn-wrong-
# 1765                             ban-plastic-water-bottles
# 1924                           gay-marriage-right-or-wrong
# ...

# %%
df_full[
    (df_full['confusion_3']==4) 
]
# Out:
#       post_id  source_dataset  \
# 0           0               0
# 1           1               0
# 6           6               0
# 9           9               0
# 12         12               0
# ...       ...             ...
# 2073     2073               0
# 2075     2075               0
# 2087     2087               0
# 2100     2100               0
# 2111     2111               1
#
#                                                                                       issue  \
# 0                                                 is-the-school-uniform-a-good-or-bad-idea-
# 1                                                 is-the-school-uniform-a-good-or-bad-idea-
# 6                                                                   tv-is-better-than-books
# 9                                                                   tv-is-better-than-books
# 12                                               india-has-the-potential-to-lead-the-world-
# ...

# %%
df_full[
    (df_full['other_1']==1) &
    (df_full['other_2']==3) &
    (df_full['emotion']!=1) &
    (df_full['confusion']!=1) &
    (df_full['commitment']!=1)
]
# Out:
#       post_id  source_dataset  \
# 472       472               0
# 523       523               0
# 775       775               2
# 1106     1106               0
# 1125     1125               0
#
#                                                                                    issue  \
# 472                                            is-the-school-uniform-a-good-or-bad-idea-
# 523                                           india-has-the-potential-to-lead-the-world-
# 775   you cant take freedom away-- Stance: freedom is a choice and you can always choose
# 1106                                                             tv-is-better-than-books
# 1125                                  should-physical-education-be-mandatory-in-schools-
#
# ...

# %%
df_full[
    (df_full['other_2']==1) 
]
# Out:
# Empty DataFrame
# Columns: [post_id, source_dataset, issue, post_text, appropriateness, emotion, emotion_1, emotion_2, commitment, commitment_1, commitment_2, confusion, confusion_1, confusion_2, confusion_3, other_, other_1, other_2]
# Index: []
